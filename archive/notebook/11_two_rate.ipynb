# %% [markdown]
# # 11 脚力 100 Hz、下位 500 Hz
#
# ## 背景
#
# LC は NMPC 100 Hz、WBC 500 Hz。速い周期は遅い解の **今この時刻の 1 点** だけを使う。この段の新しい現象は **更新レートが二つ**。脚力の中身はまだ EqualShare。WBC はまだ無い。
#
# ### 成功条件
#
#
# **判定の更新:** 05 は 10 s で完了。非制御は **10.0 s**。制御して歩く段は **20.0 s かつ 10 m**。歩く段はさらに水平 **10.0 m 以上**。ゲイトは PyMPC trot \(1.35\,\mathrm{Hz}/0.74\)、遊脚高さ \(5.6\)–\(8\,\mathrm{cm}\)（LC `swingHeight`）から大きく外さない。下の旧表（5.0 s、高い duty、数 mm リフト）は合格に使わない。旧セルと GIF は消さない。
#
# シミュレーション \(\Delta t=0.002\,\mathrm{s}\)（500 Hz）。
#
# | 量 | 条件 |
# |---|---|
# | `plan_grf` | 5 ステップに 1 回だけ呼ぶ（100 Hz） |
# | 下位 | 毎ステップ、最後の Grf を MapJT |
# | hold / 末尾 5 s | \(\ge 5.0\,\mathrm{s}\) |
# | GIF | 指令 GRF（100 Hz で階段状） |

# %%
from pathlib import Path
import sys
import numpy as np
import mujoco
from IPython.display import Image, display

here = Path.cwd().resolve()
for p in [here, *here.parents]:
    if (p / "src" / "mpc_dog").is_dir():
        sys.path.insert(0, str(p / "src"))
        break

from mpc_dog.plant.mujoco_go2 import MujocoGo2
from mpc_dog.viz.gif import render_rollout_gif

HOLD_S, ATT_TOL, Z_MIN, T_RUN = 5.0, 0.35, 0.20, 7.0
KP_SW, KD_SW, STEP_H = 300.0, 20.0, 0.02
KP_Z, KD_Z, FX_TINY = 8000.0, 400.0, 0.6
FREQ, DUTY = 1.0, 0.98
OFF = np.array([0.5, 1.0, 1.0, 0.5])

def longest_true_seconds(flags, dt):
    """内容: 連続 True の最長 [s]。"""
    best = cur = 0
    for f in flags:
        cur = cur + 1 if f else 0
        if cur > best:
            best = cur
    return best * float(dt)

def clip_torque(tau, ctrl_range):
    """内容: 01 の飽和。"""
    u = np.asarray(tau, dtype=np.float64).reshape(-1)
    return np.clip(u, ctrl_range[:, 0], ctrl_range[:, 1])

def jac_leg(model, data, geoms, i):
    """内容: 脚 i の 3x3 足ヤコビ。"""
    J = np.zeros((3, model.nv))
    mujoco.mj_jacGeom(model, data, J, None, int(geoms[i]))
    return J[:, 6 + 3 * i : 9 + 3 * i]

def plan_grf_equal(x, flags, schedule, ref):
    """内容: 08 の EqualShare。比較の一方として残す。"""
    c = np.asarray(flags, dtype=np.float64).reshape(4)
    ns = max(float(c.sum()), 1.0)
    z, vz, mass = float(x[0]), float(x[1]), float(x[2])
    zref, fx_tot = float(ref[0]), float(ref[1])
    fz_tot = mass * 9.81 + KP_Z * (zref - z) - KD_Z * vz
    grf = np.zeros((4, 3), dtype=np.float64)
    for i in range(4):
        if c[i] > 0.5:
            grf[i, 0] = fx_tot / ns
            grf[i, 2] = fz_tot / ns
    return grf

def swing_tau(Jleg, feet_i, vel_i, lift_i, phi_i, duty, freq):
    """内容: 05 の直交 PD。"""
    s = float(np.clip((phi_i - duty) / max(1e-6, 1.0 - duty), 0.0, 1.0))
    w = freq / max(1e-6, 1.0 - duty)
    p_d = lift_i.copy()
    p_d[2] = lift_i[2] + STEP_H * np.sin(np.pi * s)
    v_d = np.zeros(3)
    v_d[2] = STEP_H * np.pi * np.cos(np.pi * s) * w
    return Jleg.T @ (KP_SW * (p_d - feet_i) + KD_SW * (v_d - vel_i))

DECIM = 5  # 内容: 0.002*5=0.01 s → 100 Hz

def rollout():
    """内容: grf は 100 Hz で更新し、間は同じベクトルを再利用する。"""
    p = MujocoGo2(scene="flat", seed=0)
    dt = p.sim_dt
    n = int(round(T_RUN / dt))
    geoms = p.foot_geom_ids()
    z0 = float(p.base_pos()[2])
    phi = OFF.copy()
    lift = p.feet_pos_world().copy()
    prev = np.ones(4)
    ok = []
    grf = np.zeros((4, 3))
    n_plan = 0
    for k in range(n):
        phi = (phi + dt * FREQ) % 1.0
        c = (phi < DUTY).astype(float)
        if k % DECIM == 0:
            z = float(p.base_pos()[2])
            vz = float(p.base_lin_vel_world()[2])
            grf = plan_grf_equal(np.array([z, vz, p.mass_kg]), c, None, np.array([z0, FX_TINY]))
            n_plan += 1  # 内容: 100 Hz で何回呼んだか
        fx_hold, fz_hold = float(grf[:, 0].sum()), float(grf[:, 2].sum())  # 内容: 遅い解の合力 1 点
        ns_now = max(float(c.sum()), 1.0)
        grf_now = np.zeros((4, 3))
        for i in range(4):
            if c[i] > 0.5:
                grf_now[i, 0] = fx_hold / ns_now
                grf_now[i, 2] = fz_hold / ns_now
        feet = p.feet_pos_world()
        vel = p.feet_vel_world()
        h = np.asarray(p.data.qfrc_bias[6:], dtype=np.float64)
        tau = np.zeros(12)
        for i in range(4):
            if prev[i] > 0.5 and c[i] < 0.5:
                lift[i] = feet[i].copy()
            Jleg = jac_leg(p.model, p.data, geoms, i)
            sl = slice(3 * i, 3 * i + 3)
            tau[sl] = (h[sl] - Jleg.T @ grf_now[i]) if c[i] > 0.5 else swing_tau(Jleg, feet[i], vel[i], lift[i], phi[i], DUTY, FREQ)
        p.step(clip_torque(tau, p.model.actuator_ctrlrange))
        prev = c
        rpy = p.base_rpy()
        z = float(p.base_pos()[2])
        ok.append(abs(rpy[0]) < ATT_TOL and abs(rpy[1]) < ATT_TOL and z > Z_MIN and bool(np.isfinite(p.data.qpos).all()))
    n5 = int(round(HOLD_S / dt))
    return {"hold": longest_true_seconds(ok, dt), "last5": bool(all(ok[-n5:])), "n_plan": n_plan, "n": n, "dt": dt, "last": grf}

r = rollout()
print("hold", r["hold"], "n_plan", r["n_plan"], "expect", int(T_RUN / 0.01))
assert r["hold"] >= HOLD_S
assert r["n_plan"] <= r["n"] / DECIM + 1
print("11 PASS: two-rate held", r["hold"], "s plans", r["n_plan"])
# Out:
# /home/takuya/work/mpc_dog/.venv/lib/python3.11/site-packages/gymnasium/spaces/box.py:231: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /home/takuya/work/mpc_dog/.venv/lib/python3.11/site-packages/gymnasium/spaces/box.py:297: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# hold 7.0 n_plan 700 expect 700
# 11 PASS: two-rate held 7.0 s plans 700

# %%
st = {"phi": OFF.copy(), "prev": np.ones(4), "lift": None, "cmd": np.zeros((4, 3)), "k": 0, "z0": None}

def tau_fn(pl):
    """内容: GIF も 100 Hz 更新。"""
    dt = pl.sim_dt
    if st["lift"] is None:
        st["lift"] = pl.feet_pos_world().copy()
        st["z0"] = float(pl.base_pos()[2])
    phi = (st["phi"] + dt * FREQ) % 1.0
    c = (phi < DUTY).astype(float)
    if st["k"] % DECIM == 0:
        z = float(pl.base_pos()[2])
        vz = float(pl.base_lin_vel_world()[2])
        st["cmd"] = plan_grf_equal(np.array([z, vz, pl.mass_kg]), c, None, np.array([st["z0"], FX_TINY]))
    cmd = st["cmd"].copy()
    cmd[c < 0.5] = 0.0
    geoms = pl.foot_geom_ids()
    feet = pl.feet_pos_world()
    vel = pl.feet_vel_world()
    h = np.asarray(pl.data.qfrc_bias[6:], dtype=np.float64)
    tau = np.zeros(12)
    for i in range(4):
        if st["prev"][i] > 0.5 and c[i] < 0.5:
            st["lift"][i] = feet[i].copy()
        Jleg = jac_leg(pl.model, pl.data, geoms, i)
        sl = slice(3 * i, 3 * i + 3)
        tau[sl] = (h[sl] - Jleg.T @ cmd[i]) if c[i] > 0.5 else swing_tau(Jleg, feet[i], vel[i], st["lift"][i], phi[i], DUTY, FREQ)
    st["phi"] = phi
    st["prev"] = c
    st["k"] += 1
    return clip_torque(tau, pl.model.actuator_ctrlrange)

plant = MujocoGo2(scene="flat", seed=0)
path = render_rollout_gif(
    plant, Path("assets/11_two_rate.gif"),
    n_steps=int(round(T_RUN / plant.sim_dt)), capture_every=80, tau_fn=tau_fn,
    command_grf=lambda pl: st["cmd"],
    extra_lines=lambda pl: [f"plan_calls~{st['k']//DECIM}"],
    title="11 GRF 100 Hz  MapJT 500 Hz",
)
print(path.resolve(), path.stat().st_size, "bytes")
display(Image(filename=str(path)))
# Out:
# /home/takuya/work/mpc_dog/notebook/assets/11_two_rate.gif 1895071 bytes

# %% [markdown]
# ## 分析
#
# 遅い脚力を速い MapJT が再利用しても 5 秒持つ。GIF `11_two_rate.gif`。次は `plan_grf` の二番目の中身（重心まわりの 1 ステップ分配）。OCS2 は import しない。

# %% [markdown]
# ## 続き — 新判定では未成功
#
# 旧セルの hold 5 s と直立ループは、制御して歩く段の 20 s / 10 m では不合格である。06 の歩くモードが通るまで、この番号は進めない。失敗ログは残す。
